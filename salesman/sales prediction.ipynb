# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score

# %%
data=pd.read_csv("advertising .csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
plt.figure(figsize=(8,6))
plt.scatter(data["TV"],data["Sales"],color="red",alpha=0.5,marker="o")
plt.xlabel("Expenditure for ads on tv")
plt.ylabel("Sales")
plt.title("Expenditures for ads on tv vs Sales")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(data["Radio"],data["Sales"],color="red",alpha=0.5,marker="o")
plt.xlabel("Expenditure for ads on Radio")
plt.ylabel("Sales")
plt.title("Expenditures for ads on Radio vs Sales")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(data["Newspaper"],data["Sales"],color="red",alpha=0.5,marker="o")
plt.xlabel("Expenditure for ads on Newspaper")
plt.ylabel("Sales")
plt.title("Expenditures for ads on Newspaper vs Sales")
plt.grid(True)
plt.show()

# %%
X=data.drop(columns=["Sales"])
y=data["Sales"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(X_train)
# Out:
#         TV  Radio  Newspaper
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [180 rows x 3 columns]

# %%
print(y_train)
# Out:
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65     11.3
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    17.6
# 102    19.8
# Name: Sales, Length: 180, dtype: float64

# %%
print(X_test)
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0

# %%
print(y_test)
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    16.5
# 45     16.1
# 66     11.0
# 182     8.7
# 165    16.9
# 78      5.3
# 186    10.3
# 177    16.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# Name: Sales, dtype: float64

# %%
x_predict=model.predict(X_test)
x_predict
# Out:
# array([16.95475874, 20.34957323, 23.59840218,  9.28586421, 21.7101576 ,
#        12.53596246, 21.05310377,  8.68469708, 17.14801369, 16.60338211,
#         8.98522655,  8.43906824, 17.97485925,  8.1376273 , 12.56437833,
#        14.83238467,  8.1318945 , 17.86068584, 10.98316263, 20.43770208])

# %%
accuracy_score=model.score(X_train,y_train)*100
accu_score=model.score(X_test,y_test)*100
mse=mean_squared_error(y_test,x_predict)
r2=r2_score(y_test,x_predict)*100
print(mse)
print(accuracy_score)
print(accu_score)
print(r2)
# Out:
# 2.8583804713199896
# 90.08470190832934
# 91.25420182627616
# 91.25420182627616

# %%
new_data=[[100.3,30.0,100.0]]
predicted_sales=model.predict(new_data)
print("predicted_sales:",predicted_sales)
# Out:
# c:\Users\M. Hayagreeva Ramu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 new_data=[[100.3,30.0,100.0]]
#       2 predicted_score=model.predict(new_data)
# ----> 3 print("predicted sales:",predicted_sales)
#
# NameError: name 'predicted_sales' is not defined
